# %%
import pandas as pd
df = pd.read_csv("Market_Basket_Optimisation.csv",sep=",")
df
# Out:
#               shrimp            almonds      avocado    vegetables mix  \
# 0            burgers          meatballs         eggs               NaN
# 1            chutney                NaN          NaN               NaN
# 2             turkey            avocado          NaN               NaN
# 3      mineral water               milk   energy bar  whole wheat rice
# 4     low fat yogurt                NaN          NaN               NaN
# ...              ...                ...          ...               ...
# 7495          butter         light mayo  fresh bread               NaN
# 7496         burgers  frozen vegetables         eggs      french fries
# 7497         chicken                NaN          NaN               NaN
# 7498        escalope          green tea          NaN               NaN
# 7499            eggs    frozen smoothie  yogurt cake    low fat yogurt
#
#      green grapes whole weat flour yams cottage cheese energy drink  \
# ...

# %%
data=df.values.tolist()
newlist=[]
for i in range(0,len(data)):
    newlist.append( [x for x in data[i] if pd.isnull(x) == False])

# %%
df.shape
# Out:
# (7500, 20)

# %%
df.isnull().sum()
# Out:
# shrimp                  0
# almonds              1754
# avocado              3112
# vegetables mix       4156
# green grapes         4972
# whole weat flour     5637
# yams                 6132
# cottage cheese       6520
# energy drink         6847
# tomato juice         7106
# low fat yogurt       7245
# green tea            7347
# honey                7414
# salad                7454
# mineral water        7476
# salmon               7493
# antioxydant juice    7497
# frozen smoothie      7497
# spinach              7498
# olive oil            7500
# dtype: int64

# %%
df['almonds'].unique()
# Out:
# array(['meatballs', nan, 'avocado', 'milk', 'french fries', 'light cream',
#        'spaghetti', 'pet food', 'burgers', 'champagne', 'salmon',
#        'chocolate', 'eggs', 'fresh tuna', 'shrimp', 'sparkling water',
#        'mineral water', 'grated cheese', 'tomato sauce', 'strong cheese',
#        'ground beef', 'cake', 'frozen vegetables', 'chicken', 'bug spray',
#        'muffins', 'black tea', 'escalope', 'light mayo', 'cookies',
#        'whole wheat pasta', 'pasta', 'herb & pepper', 'strawberries',
#        'energy bar', 'energy drink', 'frozen smoothie', 'salad',
#        'low fat yogurt', 'almonds', 'soup', 'ham', 'barbecue sauce',
#        'olive oil', 'oil', 'tomatoes', 'green tea', 'cooking oil',
#        'vegetables mix', 'yams', 'honey', 'french wine', 'body spray',
#        'whole wheat rice', 'eggplant', 'tomato juice', 'bacon',
#        'yogurt cake', 'hot dogs', 'red wine', 'pancakes', 'green grapes',
# ...

# %%
df['almonds'].fillna(df['almonds'].mode()[0], inplace=True)

# %%
df['almonds'].unique()
# Out:
# array(['meatballs', 'mineral water', 'avocado', 'milk', 'french fries',
#        'light cream', 'spaghetti', 'pet food', 'burgers', 'champagne',
#        'salmon', 'chocolate', 'eggs', 'fresh tuna', 'shrimp',
#        'sparkling water', 'grated cheese', 'tomato sauce',
#        'strong cheese', 'ground beef', 'cake', 'frozen vegetables',
#        'chicken', 'bug spray', 'muffins', 'black tea', 'escalope',
#        'light mayo', 'cookies', 'whole wheat pasta', 'pasta',
#        'herb & pepper', 'strawberries', 'energy bar', 'energy drink',
#        'frozen smoothie', 'salad', 'low fat yogurt', 'almonds', 'soup',
#        'ham', 'barbecue sauce', 'olive oil', 'oil', 'tomatoes',
#        'green tea', 'cooking oil', 'vegetables mix', 'yams', 'honey',
#        'french wine', 'body spray', 'whole wheat rice', 'eggplant',
#        'tomato juice', 'bacon', 'yogurt cake', 'hot dogs', 'red wine',
#        'pancakes', 'green grapes', 'dessert wine', 'mushroom cream sauce',
# ...

# %%
df['avocado'].unique()
# Out:
# array(['eggs', nan, 'energy bar', 'shallot', 'green tea', 'mineral water',
#        'cookies', 'chicken', 'tomatoes', 'honey', 'pasta', 'ham',
#        'shrimp', 'soup', 'yams', 'light cream', 'avocado', 'strawberries',
#        'chocolate', 'salmon', 'cottage cheese', 'spaghetti', 'hot dogs',
#        'french fries', 'cereals', 'brownies', 'champagne',
#        'frozen vegetables', 'gums', 'ground beef', 'low fat yogurt',
#        'milk', 'butter', 'herb & pepper', 'escalope', 'pet food',
#        'tomato juice', 'olive oil', 'frozen smoothie',
#        'antioxydant juice', 'pepper', 'mashed potato', 'tomato sauce',
#        'cake', 'corn', 'whole wheat rice', 'candy bars', 'red wine',
#        'yogurt cake', 'meatballs', 'vegetables mix',
#        'mushroom cream sauce', 'cooking oil', 'grated cheese',
#        'fresh bread', 'flax seed', 'salt', 'energy drink', 'almonds',
#        'body spray', 'babies food', 'magazines', 'dessert wine',
# ...

# %%
df['avocado'].fillna(df['avocado'].mode()[0], inplace=True)

# %%
df['avocado'].unique()
# Out:
# array(['eggs', 'mineral water', 'energy bar', 'shallot', 'green tea',
#        'cookies', 'chicken', 'tomatoes', 'honey', 'pasta', 'ham',
#        'shrimp', 'soup', 'yams', 'light cream', 'avocado', 'strawberries',
#        'chocolate', 'salmon', 'cottage cheese', 'spaghetti', 'hot dogs',
#        'french fries', 'cereals', 'brownies', 'champagne',
#        'frozen vegetables', 'gums', 'ground beef', 'low fat yogurt',
#        'milk', 'butter', 'herb & pepper', 'escalope', 'pet food',
#        'tomato juice', 'olive oil', 'frozen smoothie',
#        'antioxydant juice', 'pepper', 'mashed potato', 'tomato sauce',
#        'cake', 'corn', 'whole wheat rice', 'candy bars', 'red wine',
#        'yogurt cake', 'meatballs', 'vegetables mix',
#        'mushroom cream sauce', 'cooking oil', 'grated cheese',
#        'fresh bread', 'flax seed', 'salt', 'energy drink', 'almonds',
#        'body spray', 'babies food', 'magazines', 'dessert wine',
# ...

# %%
df['vegetables mix'].unique()
# Out:
# array([nan, 'whole wheat rice', 'eggs', 'honey', 'spaghetti',
#        'french fries', 'pepper', 'body spray', 'pasta', 'avocado', 'milk',
#        'chocolate', 'mineral water', 'magazines', 'escalope',
#        'sparkling water', 'hot dogs', 'clothes accessories', 'white wine',
#        'tomatoes', 'soda', 'cider', 'protein bar', 'tomato sauce',
#        'green tea', 'almonds', 'carrots', 'cooking oil', 'soup', 'cake',
#        'fresh bread', 'low fat yogurt', 'pancakes', 'frozen vegetables',
#        'olive oil', 'frozen smoothie', 'water spray', 'chocolate bread',
#        'rice', 'ground beef', 'cottage cheese', 'mint green tea',
#        'french wine', 'energy bar', 'fromage blanc', 'brownies',
#        'gluten free bar', 'black tea', 'yams', 'chicken', 'green grapes',
#        'tomato juice', 'pet food', 'salmon', 'spinach', 'muffins',
#        'mayonnaise', 'energy drink', 'vegetables mix', 'candy bars',
#        'meatballs', 'light mayo', 'strawberries', 'mashed potato',
# ...

# %%
df['vegetables mix'].fillna(df['vegetables mix'].mode()[0], inplace=True)

# %%
df['vegetables mix'].unique()
# Out:
# array(['mineral water', 'whole wheat rice', 'eggs', 'honey', 'spaghetti',
#        'french fries', 'pepper', 'body spray', 'pasta', 'avocado', 'milk',
#        'chocolate', 'magazines', 'escalope', 'sparkling water',
#        'hot dogs', 'clothes accessories', 'white wine', 'tomatoes',
#        'soda', 'cider', 'protein bar', 'tomato sauce', 'green tea',
#        'almonds', 'carrots', 'cooking oil', 'soup', 'cake', 'fresh bread',
#        'low fat yogurt', 'pancakes', 'frozen vegetables', 'olive oil',
#        'frozen smoothie', 'water spray', 'chocolate bread', 'rice',
#        'ground beef', 'cottage cheese', 'mint green tea', 'french wine',
#        'energy bar', 'fromage blanc', 'brownies', 'gluten free bar',
#        'black tea', 'yams', 'chicken', 'green grapes', 'tomato juice',
#        'pet food', 'salmon', 'spinach', 'muffins', 'mayonnaise',
#        'energy drink', 'vegetables mix', 'candy bars', 'meatballs',
# ...

# %%
df['green grapes'].unique()
# Out:
# array([nan, 'green tea', 'cooking oil', 'oil', 'mineral water',
#        'protein bar', 'eggs', 'pancakes', 'avocado', 'milk', 'energy bar',
#        'french fries', 'honey', 'brownies', 'ground beef', 'body spray',
#        'corn', 'white wine', 'spaghetti', 'cookies', 'chocolate', 'soup',
#        'almonds', 'champagne', 'candy bars', 'cake', 'tomato juice',
#        'meatballs', 'whole wheat rice', 'hot dogs', 'olive oil',
#        'low fat yogurt', 'light mayo', 'fresh bread', 'french wine',
#        'spinach', 'bacon', 'escalope', 'salmon', 'clothes accessories',
#        'frozen smoothie', 'strawberries', 'chicken', 'melons',
#        'babies food', 'rice', 'butter', 'cereals', 'blueberries',
#        'extra dark chocolate', 'barbecue sauce', 'green grapes', 'chili',
#        'bramble', 'asparagus', 'toothpaste', 'strong cheese',
#        'gluten free bar', 'pepper', 'cottage cheese', 'energy drink',
#        'yams', 'whole wheat pasta', 'light cream', 'black tea',
# ...

# %%
df['green grapes'].fillna(df['green grapes'].mode()[0], inplace=True)

# %%
df['green grapes'].unique()
# Out:
# array(['green tea', 'cooking oil', 'oil', 'mineral water', 'protein bar',
#        'eggs', 'pancakes', 'avocado', 'milk', 'energy bar',
#        'french fries', 'honey', 'brownies', 'ground beef', 'body spray',
#        'corn', 'white wine', 'spaghetti', 'cookies', 'chocolate', 'soup',
#        'almonds', 'champagne', 'candy bars', 'cake', 'tomato juice',
#        'meatballs', 'whole wheat rice', 'hot dogs', 'olive oil',
#        'low fat yogurt', 'light mayo', 'fresh bread', 'french wine',
#        'spinach', 'bacon', 'escalope', 'salmon', 'clothes accessories',
#        'frozen smoothie', 'strawberries', 'chicken', 'melons',
#        'babies food', 'rice', 'butter', 'cereals', 'blueberries',
#        'extra dark chocolate', 'barbecue sauce', 'green grapes', 'chili',
#        'bramble', 'asparagus', 'toothpaste', 'strong cheese',
#        'gluten free bar', 'pepper', 'cottage cheese', 'energy drink',
#        'yams', 'whole wheat pasta', 'light cream', 'black tea',
# ...

# %%
df['whole weat flour'].unique()
# Out:
# array([nan, 'cooking oil', 'black tea', 'chocolate', 'green tea', 'honey',
#        'fresh bread', 'whole wheat rice', 'body spray', 'spaghetti',
#        'energy drink', 'cider', 'mineral water', 'extra dark chocolate',
#        'corn', 'almonds', 'eggs', 'milk', 'chicken', 'escalope',
#        'pancakes', 'olive oil', 'mint', 'oil', 'french fries',
#        'antioxydant juice', 'soda', 'hot dogs', 'fromage blanc', 'cake',
#        'soup', 'rice', 'protein bar', 'hand protein bar',
#        'frozen smoothie', 'white wine', 'mint green tea', 'salmon',
#        'low fat yogurt', 'green grapes', 'meatballs', 'light mayo',
#        'bacon', 'french wine', 'champagne', 'pet food', 'carrots',
#        'eggplant', 'cookies', 'bramble', 'salad', 'nonfat milk',
#        'asparagus', 'cottage cheese', 'melons', 'zucchini', 'mayonnaise',
#        'yogurt cake', 'gums', 'brownies', 'yams', 'burger sauce',
#        'magazines', 'light cream', 'strong cheese', 'cream',
# ...

# %%
df['whole weat flour'].fillna(df['whole weat flour'].mode()[0], inplace=True)

# %%
df['whole weat flour'].unique()
# Out:
# array(['french fries', 'cooking oil', 'black tea', 'chocolate',
#        'green tea', 'honey', 'fresh bread', 'whole wheat rice',
#        'body spray', 'spaghetti', 'energy drink', 'cider',
#        'mineral water', 'extra dark chocolate', 'corn', 'almonds', 'eggs',
#        'milk', 'chicken', 'escalope', 'pancakes', 'olive oil', 'mint',
#        'oil', 'antioxydant juice', 'soda', 'hot dogs', 'fromage blanc',
#        'cake', 'soup', 'rice', 'protein bar', 'hand protein bar',
#        'frozen smoothie', 'white wine', 'mint green tea', 'salmon',
#        'low fat yogurt', 'green grapes', 'meatballs', 'light mayo',
#        'bacon', 'french wine', 'champagne', 'pet food', 'carrots',
#        'eggplant', 'cookies', 'bramble', 'salad', 'nonfat milk',
#        'asparagus', 'cottage cheese', 'melons', 'zucchini', 'mayonnaise',
#        'yogurt cake', 'gums', 'brownies', 'yams', 'burger sauce',
#        'magazines', 'light cream', 'strong cheese', 'cream',
# ...

# %%
df['yams'].unique()
# Out:
# array([nan, 'low fat yogurt', 'salmon', 'shampoo', 'white wine',
#        'frozen smoothie', 'pancakes', 'mineral water', 'green tea',
#        'whole wheat rice', 'meatballs', 'tea', 'mayonnaise', 'eggs',
#        'olive oil', 'light mayo', 'mushroom cream sauce', 'milk', 'corn',
#        'chicken', 'light cream', 'cake', 'nonfat milk', 'barbecue sauce',
#        'strong cheese', 'french fries', 'black tea', 'cookies',
#        'blueberries', 'champagne', 'energy drink', 'body spray', 'honey',
#        'fresh bread', 'chutney', 'sandwich', 'cooking oil', 'rice',
#        'mashed potato', 'tomato juice', 'hot dogs', 'cauliflower',
#        'escalope', 'gums', 'eggplant', 'cottage cheese', 'brownies',
#        'burger sauce', 'green grapes', 'chocolate', 'melons', 'muffins',
#        'soup', 'french wine', 'mint green tea', 'avocado', 'energy bar',
#        'cider', 'salt', 'strawberries', 'green beans', 'protein bar',
# ...

# %%
df['yams'].fillna(df['yams'].mode()[0], inplace=True)

# %%
df['yams'].unique()
# Out:
# array(['green tea', 'low fat yogurt', 'salmon', 'shampoo', 'white wine',
#        'frozen smoothie', 'pancakes', 'mineral water', 'whole wheat rice',
#        'meatballs', 'tea', 'mayonnaise', 'eggs', 'olive oil',
#        'light mayo', 'mushroom cream sauce', 'milk', 'corn', 'chicken',
#        'light cream', 'cake', 'nonfat milk', 'barbecue sauce',
#        'strong cheese', 'french fries', 'black tea', 'cookies',
#        'blueberries', 'champagne', 'energy drink', 'body spray', 'honey',
#        'fresh bread', 'chutney', 'sandwich', 'cooking oil', 'rice',
#        'mashed potato', 'tomato juice', 'hot dogs', 'cauliflower',
#        'escalope', 'gums', 'eggplant', 'cottage cheese', 'brownies',
#        'burger sauce', 'green grapes', 'chocolate', 'melons', 'muffins',
#        'soup', 'french wine', 'mint green tea', 'avocado', 'energy bar',
#        'cider', 'salt', 'strawberries', 'green beans', 'protein bar',
# ...

# %%
df['cottage cheese'].unique()
# Out:
# array([nan, 'eggs', 'toothpaste', 'frozen smoothie', 'escalope',
#        'green tea', 'chocolate', 'olive oil', 'magazines', 'zucchini',
#        'hot dogs', 'green grapes', 'low fat yogurt', 'fresh bread',
#        'chili', 'tomato juice', 'gums', 'chicken', 'carrots',
#        'light cream', 'asparagus', 'white wine', 'cooking oil',
#        'pancakes', 'salt', 'strawberries', 'whole wheat rice', 'cereals',
#        'brownies', 'blueberries', 'rice', 'champagne', 'spinach',
#        'mushroom cream sauce', 'almonds', 'cake', 'melons', 'protein bar',
#        'salmon', 'tea', 'pasta', 'cottage cheese', 'french fries', 'milk',
#        'vegetables mix', 'barbecue sauce', 'french wine', ' asparagus',
#        'chutney', 'oil', 'mint', 'butter', 'gluten free bar', 'honey',
#        'shampoo', 'cookies', 'mashed potato', 'chocolate bread',
#        'pet food', 'shallot', 'green beans', 'extra dark chocolate',
#        'black tea', 'whole weat flour', 'energy drink', 'yogurt cake',
# ...

# %%
df['cottage cheese'].fillna(df['cottage cheese'].mode()[0], inplace=True)

# %%
df['cottage cheese'].unique()
# Out:
# array(['green tea', 'eggs', 'toothpaste', 'frozen smoothie', 'escalope',
#        'chocolate', 'olive oil', 'magazines', 'zucchini', 'hot dogs',
#        'green grapes', 'low fat yogurt', 'fresh bread', 'chili',
#        'tomato juice', 'gums', 'chicken', 'carrots', 'light cream',
#        'asparagus', 'white wine', 'cooking oil', 'pancakes', 'salt',
#        'strawberries', 'whole wheat rice', 'cereals', 'brownies',
#        'blueberries', 'rice', 'champagne', 'spinach',
#        'mushroom cream sauce', 'almonds', 'cake', 'melons', 'protein bar',
#        'salmon', 'tea', 'pasta', 'cottage cheese', 'french fries', 'milk',
#        'vegetables mix', 'barbecue sauce', 'french wine', ' asparagus',
#        'chutney', 'oil', 'mint', 'butter', 'gluten free bar', 'honey',
#        'shampoo', 'cookies', 'mashed potato', 'chocolate bread',
#        'pet food', 'shallot', 'green beans', 'extra dark chocolate',
#        'black tea', 'whole weat flour', 'energy drink', 'yogurt cake',
# ...

# %%
df['energy drink'].unique()
# Out:
# array([nan, 'chicken', 'escalope', 'soup', 'energy bar', 'cottage cheese',
#        'eggs', 'tomato juice', 'chocolate', 'tea', 'cooking oil', 'rice',
#        'french fries', 'barbecue sauce', 'champagne', 'light mayo',
#        'brownies', 'energy drink', 'magazines', 'shampoo', 'green tea',
#        'frozen smoothie', 'gluten free bar', 'pancakes', 'low fat yogurt',
#        'green beans', 'oil', 'mashed potato', 'fresh bread', 'mint',
#        'salmon', 'zucchini', 'clothes accessories', 'french wine',
#        'almonds', 'olive oil', 'hot dogs', 'bacon', 'burger sauce',
#        'mayonnaise', 'sandwich', 'mint green tea', 'cake',
#        'whole wheat rice', 'sparkling water', 'melons', 'protein bar',
#        'honey', 'cauliflower', 'cookies', 'cereals', 'light cream',
#        'extra dark chocolate', 'asparagus', 'eggplant', 'babies food',
#        'antioxydant juice', 'salad', 'muffins', 'mushroom cream sauce',
# ...

# %%
df['energy drink'].fillna(df['energy drink'].mode()[0], inplace=True)

# %%
df['energy drink'].unique()
# Out:
# array(['green tea', 'chicken', 'escalope', 'soup', 'energy bar',
#        'cottage cheese', 'eggs', 'tomato juice', 'chocolate', 'tea',
#        'cooking oil', 'rice', 'french fries', 'barbecue sauce',
#        'champagne', 'light mayo', 'brownies', 'energy drink', 'magazines',
#        'shampoo', 'frozen smoothie', 'gluten free bar', 'pancakes',
#        'low fat yogurt', 'green beans', 'oil', 'mashed potato',
#        'fresh bread', 'mint', 'salmon', 'zucchini', 'clothes accessories',
#        'french wine', 'almonds', 'olive oil', 'hot dogs', 'bacon',
#        'burger sauce', 'mayonnaise', 'sandwich', 'mint green tea', 'cake',
#        'whole wheat rice', 'sparkling water', 'melons', 'protein bar',
#        'honey', 'cauliflower', 'cookies', 'cereals', 'light cream',
#        'extra dark chocolate', 'asparagus', 'eggplant', 'babies food',
#        'antioxydant juice', 'salad', 'muffins', 'mushroom cream sauce',
# ...

# %%
df['tomato juice'].unique()
# Out:
# array([nan, 'extra dark chocolate', 'milk', 'french wine', 'bug spray',
#        'french fries', 'chocolate', 'champagne', 'carrots', 'yogurt cake',
#        'protein bar', 'tomato juice', 'candy bars', 'fresh bread',
#        'escalope', 'low fat yogurt', 'green tea', 'shallot', 'magazines',
#        'frozen smoothie', 'cookies', 'whole wheat rice', 'muffins',
#        'cake', 'barbecue sauce', 'mashed potato', 'pancakes', 'oil',
#        'mint', 'brownies', 'fromage blanc', 'rice', 'gluten free bar',
#        'hot dogs', 'cooking oil', 'strawberries', 'body spray',
#        'energy bar', 'sparkling water', 'asparagus', 'ketchup', 'chicken',
#        'oatmeal', 'salmon', 'zucchini', 'cottage cheese', 'black tea',
#        'hand protein bar', 'energy drink', 'gums', 'cauliflower',
#        'white wine', 'cereals', 'whole weat flour',
#        'mushroom cream sauce', 'mint green tea', 'eggs',
#        'clothes accessories', 'honey', 'light mayo', 'shampoo', 'tea',
# ...

# %%
df['tomato juice'].fillna(df['tomato juice'].mode()[0], inplace=True)

# %%
df['tomato juice'].unique()
# Out:
# array(['green tea', 'extra dark chocolate', 'milk', 'french wine',
#        'bug spray', 'french fries', 'chocolate', 'champagne', 'carrots',
#        'yogurt cake', 'protein bar', 'tomato juice', 'candy bars',
#        'fresh bread', 'escalope', 'low fat yogurt', 'shallot',
#        'magazines', 'frozen smoothie', 'cookies', 'whole wheat rice',
#        'muffins', 'cake', 'barbecue sauce', 'mashed potato', 'pancakes',
#        'oil', 'mint', 'brownies', 'fromage blanc', 'rice',
#        'gluten free bar', 'hot dogs', 'cooking oil', 'strawberries',
#        'body spray', 'energy bar', 'sparkling water', 'asparagus',
#        'ketchup', 'chicken', 'oatmeal', 'salmon', 'zucchini',
#        'cottage cheese', 'black tea', 'hand protein bar', 'energy drink',
#        'gums', 'cauliflower', 'white wine', 'cereals', 'whole weat flour',
#        'mushroom cream sauce', 'mint green tea', 'eggs',
#        'clothes accessories', 'honey', 'light mayo', 'shampoo', 'tea',
# ...

# %%
df['low fat yogurt'].unique()
# Out:
# array([nan, 'olive oil', 'eggs', 'pancakes', 'tomato juice',
#        'frozen smoothie', 'brownies', 'cookies', 'protein bar',
#        'low fat yogurt', 'green tea', 'mint', 'light mayo', 'fresh bread',
#        'toothpaste', 'sandwich', 'chocolate', 'chicken', 'cake', 'salt',
#        'cereals', 'melons', 'french fries', 'whole wheat rice',
#        'mayonnaise', 'salad', 'champagne', 'honey', 'cottage cheese',
#        'eggplant', 'strawberries', 'yogurt cake', 'energy drink',
#        'salmon', 'spinach', 'escalope', 'gums', 'white wine',
#        'mushroom cream sauce', 'cooking oil', 'hand protein bar',
#        'whole weat flour', 'magazines', 'babies food', 'oil',
#        'extra dark chocolate', 'carrots', 'cauliflower', 'chili',
#        'clothes accessories', 'hot dogs', 'rice', 'body spray',
#        'nonfat milk', 'candy bars', 'strong cheese', 'black tea',
#        'ketchup', 'sparkling water', 'chocolate bread', 'corn', 'muffins',
# ...

# %%
df['low fat yogurt'].fillna(df['low fat yogurt'].mode()[0], inplace=True)

# %%
df['low fat yogurt'].unique()
# Out:
# array(['low fat yogurt', 'olive oil', 'eggs', 'pancakes', 'tomato juice',
#        'frozen smoothie', 'brownies', 'cookies', 'protein bar',
#        'green tea', 'mint', 'light mayo', 'fresh bread', 'toothpaste',
#        'sandwich', 'chocolate', 'chicken', 'cake', 'salt', 'cereals',
#        'melons', 'french fries', 'whole wheat rice', 'mayonnaise',
#        'salad', 'champagne', 'honey', 'cottage cheese', 'eggplant',
#        'strawberries', 'yogurt cake', 'energy drink', 'salmon', 'spinach',
#        'escalope', 'gums', 'white wine', 'mushroom cream sauce',
#        'cooking oil', 'hand protein bar', 'whole weat flour', 'magazines',
#        'babies food', 'oil', 'extra dark chocolate', 'carrots',
#        'cauliflower', 'chili', 'clothes accessories', 'hot dogs', 'rice',
#        'body spray', 'nonfat milk', 'candy bars', 'strong cheese',
#        'black tea', 'ketchup', 'sparkling water', 'chocolate bread',
#        'corn', 'muffins', 'tea', 'bramble', 'barbecue sauce',
# ...

# %%
df['green tea'].unique()
# Out:
# array([nan, 'salt', 'low fat yogurt', 'fresh bread', 'tomato juice',
#        'magazines', 'mint', 'white wine', 'escalope', 'french fries',
#        'extra dark chocolate', 'cake', 'protein bar', 'frozen smoothie',
#        'green tea', 'cereals', 'cookies', 'ketchup', 'strawberries',
#        'honey', 'melons', 'whole wheat rice', 'mashed potato', 'eggs',
#        'vegetables mix', 'chocolate', 'hot dogs', 'eggplant',
#        'blueberries', 'rice', 'pancakes', 'brownies', 'champagne', 'ham',
#        'candy bars', 'energy drink', 'corn', 'cottage cheese', 'shampoo',
#        'chicken', 'green grapes', 'light mayo', 'mushroom cream sauce',
#        'strong cheese', 'whole weat flour', 'mayonnaise', 'cooking oil',
#        'body spray', 'toothpaste', 'zucchini', 'gluten free bar'],
#       dtype=object)

# %%
df['green tea'].fillna(df['green tea'].mode()[0], inplace=True)

# %%
df['green tea'].unique()
# Out:
# array(['green tea', 'salt', 'low fat yogurt', 'fresh bread',
#        'tomato juice', 'magazines', 'mint', 'white wine', 'escalope',
#        'french fries', 'extra dark chocolate', 'cake', 'protein bar',
#        'frozen smoothie', 'cereals', 'cookies', 'ketchup', 'strawberries',
#        'honey', 'melons', 'whole wheat rice', 'mashed potato', 'eggs',
#        'vegetables mix', 'chocolate', 'hot dogs', 'eggplant',
#        'blueberries', 'rice', 'pancakes', 'brownies', 'champagne', 'ham',
#        'candy bars', 'energy drink', 'corn', 'cottage cheese', 'shampoo',
#        'chicken', 'green grapes', 'light mayo', 'mushroom cream sauce',
#        'strong cheese', 'whole weat flour', 'mayonnaise', 'cooking oil',
#        'body spray', 'toothpaste', 'zucchini', 'gluten free bar'],
#       dtype=object)

# %%
df['honey'].unique()
# Out:
# array([nan, 'fresh bread', 'hot dogs', 'low fat yogurt', 'pancakes',
#        'champagne', 'mint', 'cookies', 'green tea', 'protein bar', 'gums',
#        'oil', 'energy drink', 'salad', 'tea', 'brownies', 'french fries',
#        'nonfat milk', 'salt', 'corn', 'melons', 'sparkling water',
#        'light mayo', 'cooking oil', 'burger sauce', 'white wine',
#        'yogurt cake', 'tomato juice', 'frozen smoothie', 'escalope',
#        'eggplant', 'ham', 'cottage cheese', 'whole wheat rice',
#        'toothpaste', 'bug spray', 'asparagus', 'magazines',
#        'barbecue sauce', 'cauliflower', 'cereals', 'mashed potato',
#        'zucchini'], dtype=object)

# %%
df['honey'].fillna(df['honey'].mode()[0], inplace=True)

# %%
df['honey'].unique()
# Out:
# array(['green tea', 'fresh bread', 'hot dogs', 'low fat yogurt',
#        'pancakes', 'champagne', 'mint', 'cookies', 'protein bar', 'gums',
#        'oil', 'energy drink', 'salad', 'tea', 'brownies', 'french fries',
#        'nonfat milk', 'salt', 'corn', 'melons', 'sparkling water',
#        'light mayo', 'cooking oil', 'burger sauce', 'white wine',
#        'yogurt cake', 'tomato juice', 'frozen smoothie', 'escalope',
#        'eggplant', 'ham', 'cottage cheese', 'whole wheat rice',
#        'toothpaste', 'bug spray', 'asparagus', 'magazines',
#        'barbecue sauce', 'cauliflower', 'cereals', 'mashed potato',
#        'zucchini'], dtype=object)

# %%
df['salad'].unique()
# Out:
# array([nan, 'green tea', 'hot dogs', 'salt', 'mint', 'oil',
#        'mineral water', 'fresh bread', 'toothpaste', 'pancakes',
#        'cottage cheese', 'muffins', 'babies food', 'french fries',
#        'hand protein bar', 'frozen smoothie', 'light mayo', 'protein bar',
#        'mushroom cream sauce', 'escalope', 'strawberries',
#        'gluten free bar', 'low fat yogurt', 'eggplant', 'eggs',
#        'yogurt cake', 'salad', 'cookies', 'tomato juice'], dtype=object)

# %%
df['salad'].fillna(df['salad'].mode()[0], inplace=True)

# %%
df['salad'].unique()
# Out:
# array(['green tea', 'hot dogs', 'salt', 'mint', 'oil', 'mineral water',
#        'fresh bread', 'toothpaste', 'pancakes', 'cottage cheese',
#        'muffins', 'babies food', 'french fries', 'hand protein bar',
#        'frozen smoothie', 'light mayo', 'protein bar',
#        'mushroom cream sauce', 'escalope', 'strawberries',
#        'gluten free bar', 'low fat yogurt', 'eggplant', 'eggs',
#        'yogurt cake', 'salad', 'cookies', 'tomato juice'], dtype=object)

# %%
df['mineral water'].unique()
# Out:
# array([nan, 'cereals', 'salmon', 'candy bars', 'clothes accessories',
#        'pancakes', 'magazines', 'cookies', 'zucchini', 'tomato juice',
#        'hot dogs', 'fresh bread', 'toothpaste', 'hand protein bar',
#        'low fat yogurt', 'green tea', 'yogurt cake', 'mint',
#        'mushroom cream sauce'], dtype=object)

# %%
df['mineral water'].fillna(df['mineral water'].mode()[0], inplace=True)

# %%
df['mineral water'].unique()
# Out:
# array(['magazines', 'cereals', 'salmon', 'candy bars',
#        'clothes accessories', 'pancakes', 'cookies', 'zucchini',
#        'tomato juice', 'hot dogs', 'fresh bread', 'toothpaste',
#        'hand protein bar', 'low fat yogurt', 'green tea', 'yogurt cake',
#        'mint', 'mushroom cream sauce'], dtype=object)

# %%
df['salmon'].unique()
# Out:
# array([nan, 'chocolate', 'antioxydant juice', 'frozen smoothie', 'cake',
#        'sparkling water', 'protein bar', 'magazines'], dtype=object)

# %%
df['salmon'].fillna(df['salmon'].mode()[0], inplace=True)

# %%
df['salmon'].unique()
# Out:
# array(['antioxydant juice', 'chocolate', 'frozen smoothie', 'cake',
#        'sparkling water', 'protein bar', 'magazines'], dtype=object)

# %%
df['antioxydant juice'].unique()
# Out:
# array([nan, 'frozen smoothie', 'french fries'], dtype=object)

# %%
df['antioxydant juice'].fillna(df['antioxydant juice'].mode()[0], inplace=True)

# %%
df['antioxydant juice'].unique()
# Out:
# array(['frozen smoothie', 'french fries'], dtype=object)

# %%
df['frozen smoothie'].unique()
# Out:
# array([nan, 'protein bar', 'spinach'], dtype=object)

# %%
df['frozen smoothie'].fillna(df['frozen smoothie'].mode()[0], inplace=True)

# %%
df['frozen smoothie'].unique()
# Out:
# array(['protein bar', 'spinach'], dtype=object)

# %%
df['spinach'].unique()
# Out:
# array([nan, 'mayonnaise', 'cereals'], dtype=object)

# %%
df['spinach'].fillna(df['spinach'].mode()[0], inplace=True)

# %%
df['spinach'].unique()
# Out:
# array(['cereals', 'mayonnaise'], dtype=object)

# %%
df['olive oil'].unique()
# Out:
# array([nan])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   shrimp             7500 non-null   object
#  1   almonds            7500 non-null   object
#  2   avocado            7500 non-null   object
#  3   vegetables mix     7500 non-null   object
#  4   green grapes       7500 non-null   object
#  5   whole weat flour   7500 non-null   object
#  6   yams               7500 non-null   object
#  7   cottage cheese     7500 non-null   object
#  8   energy drink       7500 non-null   object
#  9   tomato juice       7500 non-null   object
#  10  low fat yogurt     7500 non-null   object
#  11  green tea          7500 non-null   object
#  12  honey              7500 non-null   object
#  13  salad              7500 non-null   object
#  14  mineral water      7500 non-null   object
#  15  salmon             7500 non-null   object
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le= LabelEncoder()
df['shrimp']= le.fit_transform(df['shrimp'])
df['almonds']= le.fit_transform(df['almonds'])
df['avocado']= le.fit_transform(df['avocado'])
df['vegetables mix']= le.fit_transform(df['vegetables mix'])
df['green grapes']= le.fit_transform(df['green grapes'])
df['whole weat flour']= le.fit_transform(df['whole weat flour'])
df['yams']= le.fit_transform(df['yams'])
df['cottage cheese']= le.fit_transform(df['cottage cheese'])
df['energy drink']= le.fit_transform(df['energy drink'])
df['tomato juice']= le.fit_transform(df['tomato juice'])
df['low fat yogurt']= le.fit_transform(df['low fat yogurt'])
df['green tea']= le.fit_transform(df['green tea'])
df['honey']= le.fit_transform(df['honey'])
df['salad']= le.fit_transform(df['salad'])
df['mineral water']= le.fit_transform(df['mineral water'])
df['salmon']= le.fit_transform(df['salmon'])
df['antioxydant juice']= le.fit_transform(df['antioxydant juice'])
df['frozen smoothie']= le.fit_transform(df['frozen smoothie'])
df['spinach']= le.fit_transform(df['spinach'])
df
# Out:
#       shrimp  almonds  avocado  vegetables mix  green grapes  \
# 0         14       67       34              68            49
# 1         26       70       69              68            49
# 2        107        3       69              68            49
# 3         71       69       35             110            49
# 4         64       70       69              68            49
# ...      ...      ...      ...             ...           ...
# 7495      15       62       42              68            49
# 7496      14       47       34              40            60
# 7497      22       70       69              68            49
# 7498      39       52       69              68            49
# 7499      36       46      113              61            49
#
#       whole weat flour  yams  cottage cheese  energy drink  tomato juice  \
# 0                   40    47              48            44            37
# 1                   40    47              48            44            37
# ...

# %%
df1= df.drop('olive oil',axis=1)
df1
# Out:
#       shrimp  almonds  avocado  vegetables mix  green grapes  \
# 0         14       67       34              68            49
# 1         26       70       69              68            49
# 2        107        3       69              68            49
# 3         71       69       35             110            49
# 4         64       70       69              68            49
# ...      ...      ...      ...             ...           ...
# 7495      15       62       42              68            49
# 7496      14       47       34              40            60
# 7497      22       70       69              68            49
# 7498      39       52       69              68            49
# 7499      36       46      113              61            49
#
#       whole weat flour  yams  cottage cheese  energy drink  tomato juice  \
# 0                   40    47              48            44            37
# 1                   40    47              48            44            37
# ...

# %%
# !pip install squarify

# %%
import matplotlib.pyplot as plt
import numpy as np

x_data = df['shrimp']
y_data = df['cottage cheese']
def scatterplot(x_data, y_data, x_label= "shrimp", y_label= "cottage cheese", color = "r", yscale_log=False):

    # Create the plot object
    _, ax = plt.subplots()

    # Plot the data, set the size (s), color and transparency (alpha)
    # of the points
    ax.scatter(x_data, y_data, s = 10, color = color, alpha = 0.75)

    if yscale_log == True:
        ax.set_yscale('log')

    # Label the axes and provide a title
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)

scatterplot(x_data, y_data)

# %%
x_data = df['shrimp']
y_data = df['cottage cheese']
def barplot(x_data, y_data, x_label="shrimp", y_label="cottage cheese"):
    _, ax = plt.subplots()
    # Draw bars, position them in the center of the tick mark on the x-axis
    ax.bar(x_data, y_data, color = '#539caf', align = 'center')
    # Draw error bars to show standard deviation, set ls to 'none'
    # to remove line between points
    ax.errorbar(x_data, y_data, color = '#297083', ls = 'none', lw = 2, capthick = 2)
    ax.set_ylabel(y_label)
    ax.set_xlabel(x_label)
barplot(x_data, y_data)

# %%
import matplotlib as mpl
mpl.rcParams['lines.linewidth'] = 2
mpl.rcParams['lines.linestyle'] = '--'
plt.plot(df1)

# %%
import seaborn as sns

sns.regplot(x='shrimp',y='avocado', data=df)

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %%
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.animation as animation

# Fixing random state for reproducibility
np.random.seed(19680801)
# Fixing bin edges
HIST_BINS = np.linspace(-4, 4, 100)

# histogram our data with numpy
df1 = np.random.randn(1000)
n, _ = np.histogram(df1, HIST_BINS)

# %%
def prepare_animation(bar_container):

    def animate(frame_number):
        # simulate new data coming in
        df1 = np.random.randn(1000)
        n, _ = np.histogram(df1, HIST_BINS)
        for count, rect in zip(n, bar_container.patches):
            rect.set_height(count)
        return bar_container.patches
    return animate

# %%
fig, ax = plt.subplots()
_, _, bar_container = ax.hist(data, HIST_BINS, lw=1,
                              ec="yellow", fc="green", alpha=0.5)
ax.set_ylim(top=55)  # set safe limit to ensure that all data is visible.

ani = animation.FuncAnimation(fig, prepare_animation(bar_container), 50,
                              repeat=False, blit=True)
plt.show()
# Out:
# Traceback (most recent call last):
#   File "C:\Users\FUJITSU\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py", line 196, in process
#     func(*args, **kwargs)
#   File "C:\Users\FUJITSU\anaconda3\lib\site-packages\matplotlib\animation.py", line 951, in _start
#     self._init_draw()
#   File "C:\Users\FUJITSU\anaconda3\lib\site-packages\matplotlib\animation.py", line 1743, in _init_draw
#     self._draw_frame(next(self.new_frame_seq()))
#   File "C:\Users\FUJITSU\anaconda3\lib\site-packages\matplotlib\animation.py", line 1766, in _draw_frame
#     self._drawn_artists = self._func(framedata, *self._args)
#   File "<ipython-input-79-b7a87bc9d06b>", line 7, in animate
#     for count, rect in zip(n, bar_container.patches):
# AttributeError: 'silent_list' object has no attribute 'patches'

# %%
import mlxtend
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
te=TransactionEncoder()
te_ary=te.fit(newlist).transform(newlist)    #Apply one-hot-encoding on our dataset
df1=pd.DataFrame(te_ary, columns=te.columns_)  #Creating a new DataFrame from our Numpy array
df1
# Out:
#        asparagus  almonds  antioxydant juice  asparagus  avocado  babies food  \
# 0          False    False              False      False    False        False
# 1          False    False              False      False    False        False
# 2          False    False              False      False     True        False
# 3          False    False              False      False    False        False
# 4          False    False              False      False    False        False
# ...          ...      ...                ...        ...      ...          ...
# 7495       False    False              False      False    False        False
# 7496       False    False              False      False    False        False
# 7497       False    False              False      False    False        False
# 7498       False    False              False      False    False        False
# 7499       False    False              False      False    False        False
#
# ...

# %%
from mlxtend.frequent_patterns import apriori
frequent_itemsets = apriori(df1, min_support=0.01)
frequent_itemsets
# Out:
#       support       itemsets
# 0    0.020267            (1)
# 1    0.033200            (4)
# 2    0.010800            (7)
# 3    0.014267            (8)
# 4    0.011467           (10)
# ..        ...            ...
# 254  0.011067   (72, 71, 55)
# 255  0.017067  (72, 100, 55)
# 256  0.015733  (72, 100, 71)
# 257  0.010267  (72, 81, 100)
# 258  0.011467  (72, 82, 100)
#
# [259 rows x 2 columns]

# %%
from mlxtend.frequent_patterns import association_rules
association_rules(frequent_itemsets,metric="confidence",min_threshold=0.2)
# Out:
#     antecedents consequents  antecedent support  consequent support   support  \
# 0           (4)        (72)            0.033200            0.238267  0.011467
# 1          (15)        (37)            0.087200            0.179733  0.028800
# 2          (15)        (43)            0.087200            0.170933  0.022000
# 3          (15)        (54)            0.087200            0.132000  0.017467
# 4          (15)        (71)            0.087200            0.129600  0.017867
# ..          ...         ...                 ...                 ...       ...
# 157   (100, 71)        (72)            0.035467            0.238267  0.015733
# 158    (72, 81)       (100)            0.027467            0.174133  0.010267
# 159   (81, 100)        (72)            0.022933            0.238267  0.010267
# 160    (72, 82)       (100)            0.033733            0.174133  0.011467
# 161   (82, 100)        (72)            0.025200            0.238267  0.011467
#
# ...

# %%
association_rules(frequent_itemsets,metric="lift",min_threshold=2)
# Out:
#    antecedents consequents  antecedent support  consequent support   support  \
# 0         (49)        (97)            0.095333            0.071333  0.016667
# 1         (97)        (49)            0.071333            0.095333  0.016667
# 2         (49)       (108)            0.095333            0.068400  0.016133
# 3        (108)        (49)            0.068400            0.095333  0.016133
# 4         (51)        (55)            0.052400            0.098267  0.011333
# 5         (55)        (51)            0.098267            0.052400  0.011333
# 6         (59)        (55)            0.049467            0.098267  0.016000
# 7         (55)        (59)            0.098267            0.049467  0.016000
# 8         (81)        (55)            0.065733            0.098267  0.014133
# 9         (55)        (81)            0.098267            0.065733  0.014133
# 10       (100)        (55)            0.174133            0.098267  0.039200
# ...

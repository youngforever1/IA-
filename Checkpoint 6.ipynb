# %%
import pandas as pd
df = pd.read_csv("iris.data.csv",sep=",")
df
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
import csv 
import random

def loadDataset(filename, split, trainingSet=[] , testSet=[]):
    
    with open(filename, 'r') as csvfile:
        lines = csv.reader(csvfile)
        dataset = list(lines)
    
    for x in range(len(dataset)-1):
        for y in range(4):

            dataset[x][y] = float(dataset[x][y])

        if random.random() < split:

            trainingSet.append(dataset[x])

        else:

            testSet.append(dataset[x])
trainingSet=[]

testSet=[]

loadDataset('iris.data.csv', 0.66, trainingSet, testSet)

print ('Train: ' + repr(len(trainingSet)))

print ('Test: ' + repr(len(testSet)) )
# Out:
# Train: 103
# Test: 46

# %%
import math
def euclideanDistance(instance1, instance2, length):
    d = 0
    for i in range(length):
        d = d + math.pow(instance1[i]-instance2[i],2)
    return math.sqrt(d)
data1 = [2, 2, 2]

data2 = [4, 4, 4]
lenn = len(data1)

distance = euclideanDistance(data1, data2, lenn)

print('Distance: ' + repr(distance))
# Out:
# Distance: 3.4641016151377544

# %%
import operator

def getNeighbors(trainingSet, testInstance, k):

    distances = []

    length = len(testInstance)-1

    for x in range(len(trainingSet)):

        dist = euclideanDistance(testInstance, trainingSet[x], length)

        distances.append((trainingSet[x], dist))

        distances.sort(key=operator.itemgetter(1))

    neighbors = []

    for x in range(k):

        neighbors.append(distances[x][0])

    return neighbors


trainSet = [[2, 2, 2, 'a'], [4, 4, 4, 'b']]

testInstance = [5, 5, 5]

k = 1

neighbors = getNeighbors(trainSet, testInstance, 1)

print(neighbors)
# Out:
# [[4, 4, 4, 'b']]

# %%
import operator

def getResponse(neighbors):

    classVotes = {}

    for x in range(len(neighbors)):

        response = neighbors[x][3] #complete with appropriate number
    
    if response in classVotes:

        classVotes[response]+=1
    
    else:
        
        classVotes[response] = 1
        
        sortedVotes = sorted(classVotes.items(), key=operator.itemgetter(1), reverse=True)

    return sortedVotes[0][0]


neighbors = [[1,1,1,'a'], [2,2,2,'a'], [3,3,3,'b']]

response = getResponse(neighbors)

print(response)
# Out:
# b

# %%
def getAccuracy(testSet, predictions):

    correct = 0
    for i in range(len(testSet)):
        if testSet[i][-1] == predictions[i]:
            correct += 1
    return (correct/float(len(testSet))) * 100.0


testSet = [[1,1,1,'a'], [2,2,2,'a'], [3,3,3,'b']]

predictions = ['a', 'a', 'a']

accuracy = getAccuracy(testSet, predictions)

print(accuracy)
# Out:
# 66.66666666666666

# %%
def main():
    trainingSet=[] 
    testSet=[]
        
loadDataset('iris.data.csv', 0.66, trainingSet, testSet)

print ('Train: ' + repr(len(trainingSet)))

print ('Test: ' + repr(len(testSet)) )
predictions=[]
k = 3
for x in range(len(testSet)):
    neighbors = getNeighbors(trainingSet, testSet[x], k)
    response = getResponse(neighbors)
    predictions.append(response)
    print('Predicted is  ' + repr(response) + ' Actual is  ' + repr(testSet[x][-1]))
accuracy = getAccuracy(testSet, predictions)
print('Accuracy: ' + repr(accuracy) + '%')
# Out:
# Train: 196
# Test: 56
# Predicted is  0.1 Actual is  'a'
# Predicted is  0.2 Actual is  'a'
# Predicted is  1.0 Actual is  'b'
# Predicted is  0.2 Actual is  'Iris-setosa'
# Predicted is  0.2 Actual is  'Iris-setosa'
# Predicted is  0.2 Actual is  'Iris-setosa'
# Predicted is  0.2 Actual is  'Iris-setosa'
# Predicted is  0.4 Actual is  'Iris-setosa'
# Predicted is  0.2 Actual is  'Iris-setosa'
# Predicted is  0.2 Actual is  'Iris-setosa'
# Predicted is  0.2 Actual is  'Iris-setosa'
# Predicted is  0.3 Actual is  'Iris-setosa'
# Predicted is  0.2 Actual is  'Iris-setosa'
# Predicted is  0.2 Actual is  'Iris-setosa'
# Predicted is  0.2 Actual is  'Iris-setosa'
# Predicted is  0.3 Actual is  'Iris-setosa'
# Predicted is  0.2 Actual is  'Iris-setosa'
# Predicted is  0.2 Actual is  'Iris-setosa'
# Predicted is  0.2 Actual is  'Iris-setosa'
# Predicted is  1.6 Actual is  'Iris-versicolor'
# Predicted is  1.4 Actual is  'Iris-versicolor'
# Predicted is  1.3 Actual is  'Iris-versicolor'
# Predicted is  1.0 Actual is  'Iris-versicolor'
# Predicted is  1.5 Actual is  'Iris-versicolor'
# Predicted is  1.2 Actual is  'Iris-versicolor'
# Predicted is  1.2 Actual is  'Iris-versicolor'
# Predicted is  1.5 Actual is  'Iris-versicolor'
# Predicted is  1.3 Actual is  'Iris-versicolor'
# Predicted is  1.5 Actual is  'Iris-versicolor'
# Predicted is  1.5 Actual is  'Iris-versicolor'
# Predicted is  1.0 Actual is  'Iris-versicolor'
# Predicted is  1.8 Actual is  'Iris-versicolor'
# Predicted is  1.3 Actual is  'Iris-versicolor'
# Predicted is  1.3 Actual is  'Iris-versicolor'
# Predicted is  1.2 Actual is  'Iris-versicolor'
# Predicted is  1.3 Actual is  'Iris-versicolor'
# Predicted is  1.0 Actual is  'Iris-versicolor'
# Predicted is  1.6 Actual is  'Iris-versicolor'
# Predicted is  1.4 Actual is  'Iris-versicolor'
# Predicted is  1.2 Actual is  'Iris-versicolor'
# Predicted is  1.3 Actual is  'Iris-versicolor'
# Predicted is  1.5 Actual is  'Iris-versicolor'
# Predicted is  1.3 Actual is  'Iris-versicolor'
# Predicted is  1.8 Actual is  'Iris-virginica'
# Predicted is  2.3 Actual is  'Iris-virginica'
# Predicted is  1.9 Actual is  'Iris-virginica'
# Predicted is  2.3 Actual is  'Iris-virginica'
# Predicted is  1.9 Actual is  'Iris-virginica'
# Predicted is  1.9 Actual is  'Iris-virginica'
# Predicted is  1.8 Actual is  'Iris-virginica'
# Predicted is  2.1 Actual is  'Iris-virginica'
# Predicted is  1.8 Actual is  'Iris-virginica'
# Predicted is  1.8 Actual is  'Iris-virginica'
# Predicted is  2.3 Actual is  'Iris-virginica'
# Predicted is  2.3 Actual is  'Iris-virginica'
# Predicted is  2.0 Actual is  'Iris-virginica'
# Accuracy: 0.0%

# %%
import pandas as pd
df = pd.read_csv("iris.data.csv",sep=",")
df
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
import csv 
import random

def loadDataset(filename, split, trainingSet=[] , testSet=[]):
    
    with open(filename, 'r') as csvfile:
        lines = csv.reader(csvfile)
        dataset = list(lines)
    
    for x in range(len(dataset)-1):
        for y in range(4):

            dataset[x][y] = float(dataset[x][y])

        if random.random() < split:

            trainingSet.append(dataset[x])

        else:

            testSet.append(dataset[x])
    
    
loadDataset('iris.data.csv', 0.66)
trainingSet=[]

testSet=[]

loadDataset('iris.data.csv', 0.66, trainingSet, testSet)

print ('Train: ' + repr(len(trainingSet)))

print ('Test: ' + repr(len(testSet)) )
# Out:
# Train: 100
# Test: 49

# %%
import math
def ManhattanDistance(instance1, instance2, length):
    d = 0
    for i in range(length):
        d = d + abs(instance1[i]-instance2[i])
    return (d)
data1 = [2, 2, 2]

data2 = [4, 4, 4]
lenn = len(data1)

distance = ManhattanDistance(data1, data2, lenn)

print('Distance: ' + repr(distance))
# Out:
# Distance: 6

# %%
import operator

def getNeighbors(trainingSet, testInstance, k):

    distances = []

    length = len(testInstance)-1

    for x in range(len(trainingSet)):

        dist = ManhattanDistance(testInstance, trainingSet[x], length)

        distances.append((trainingSet[x], dist))

        distances.sort(key=operator.itemgetter(1))

    neighbors = []

    for x in range(k):

        neighbors.append(distances[x][0])

    return neighbors


trainSet = [[2, 2, 2, 'a'], [4, 4, 4, 'b']]

testInstance = [5, 5, 5]

k = 1

neighbors = getNeighbors(trainSet, testInstance, 1)

print(neighbors)
# Out:
# [[4, 4, 4, 'b']]

# %%
import operator

def getResponse(neighbors):

    classVotes = {}

    for x in range(len(neighbors)):

        response = neighbors[x][3] #complete with appropriate number
    
    if response in classVotes:

        classVotes[response]+=1
    
    else:
        
        classVotes[response] = 1
        
        sortedVotes = sorted(classVotes.items(), key=operator.itemgetter(1), reverse=True)

    return sortedVotes[0][0]


neighbors = [[1,1,1,'a'], [2,2,2,'a'], [3,3,3,'b']]

response = getResponse(neighbors)

print(response)
# Out:
# b

# %%
def getAccuracy(testSet, predictions):

    correct = 0
    for i in range(len(testSet)):
        if testSet[i][-1] == predictions[i]:
            correct += 1
    return (correct/float(len(testSet))) * 100.0


testSet = [[1,1,1,'a'], [2,2,2,'a'], [3,3,3,'b']]

predictions = ['a', 'a', 'a']

accuracy = getAccuracy(testSet, predictions)

print(accuracy)
# Out:
# 66.66666666666666

# %%
def main():
    trainingSet=[] 
    testSet=[]
        
loadDataset('iris.data.csv', 0.66, trainingSet, testSet)

print ('Train: ' + repr(len(trainingSet)))

print ('Test: ' + repr(len(testSet)) )
predictions=[]
k = 3
for x in range(len(testSet)):
    neighbors = getNeighbors(trainingSet, testSet[x], k)
    response = getResponse(neighbors)
    predictions.append(response)
    print('Predicted is  ' + repr(response) + ' Actual is  ' + repr(testSet[x][-1]))
accuracy = getAccuracy(testSet, predictions)
print('Accuracy: ' + repr(accuracy) + '%')
# Out:
# Train: 299
# Test: 102
# Predicted is  0.3 Actual is  'a'
# Predicted is  0.3 Actual is  'a'
# Predicted is  1.1 Actual is  'b'
# Predicted is  0.2 Actual is  'Iris-setosa'
# Predicted is  0.2 Actual is  'Iris-setosa'
# Predicted is  0.2 Actual is  'Iris-setosa'
# Predicted is  0.2 Actual is  'Iris-setosa'
# Predicted is  0.4 Actual is  'Iris-setosa'
# Predicted is  0.3 Actual is  'Iris-setosa'
# Predicted is  0.3 Actual is  'Iris-setosa'
# Predicted is  0.2 Actual is  'Iris-setosa'
# Predicted is  0.2 Actual is  'Iris-setosa'
# Predicted is  0.2 Actual is  'Iris-setosa'
# Predicted is  0.2 Actual is  'Iris-setosa'
# Predicted is  0.2 Actual is  'Iris-setosa'
# Predicted is  0.3 Actual is  'Iris-setosa'
# Predicted is  0.3 Actual is  'Iris-setosa'
# Predicted is  0.2 Actual is  'Iris-setosa'
# Predicted is  0.2 Actual is  'Iris-setosa'
# Predicted is  1.6 Actual is  'Iris-versicolor'
# Predicted is  1.5 Actual is  'Iris-versicolor'
# Predicted is  1.3 Actual is  'Iris-versicolor'
# Predicted is  1.0 Actual is  'Iris-versicolor'
# Predicted is  1.4 Actual is  'Iris-versicolor'
# Predicted is  1.3 Actual is  'Iris-versicolor'
# Predicted is  1.0 Actual is  'Iris-versicolor'
# Predicted is  1.4 Actual is  'Iris-versicolor'
# Predicted is  1.3 Actual is  'Iris-versicolor'
# Predicted is  1.4 Actual is  'Iris-versicolor'
# Predicted is  1.5 Actual is  'Iris-versicolor'
# Predicted is  1.3 Actual is  'Iris-versicolor'
# Predicted is  1.8 Actual is  'Iris-versicolor'
# Predicted is  1.4 Actual is  'Iris-versicolor'
# Predicted is  1.4 Actual is  'Iris-versicolor'
# Predicted is  1.0 Actual is  'Iris-versicolor'
# Predicted is  1.1 Actual is  'Iris-versicolor'
# Predicted is  1.2 Actual is  'Iris-versicolor'
# Predicted is  1.5 Actual is  'Iris-versicolor'
# Predicted is  1.4 Actual is  'Iris-versicolor'
# Predicted is  1.3 Actual is  'Iris-versicolor'
# Predicted is  1.3 Actual is  'Iris-versicolor'
# Predicted is  1.4 Actual is  'Iris-versicolor'
# Predicted is  1.3 Actual is  'Iris-versicolor'
# Predicted is  1.8 Actual is  'Iris-virginica'
# Predicted is  2.0 Actual is  'Iris-virginica'
# Predicted is  1.9 Actual is  'Iris-virginica'
# Predicted is  2.1 Actual is  'Iris-virginica'
# Predicted is  2.1 Actual is  'Iris-virginica'
# Predicted is  1.8 Actual is  'Iris-virginica'
# Predicted is  1.6 Actual is  'Iris-virginica'
# Predicted is  1.8 Actual is  'Iris-virginica'
# Predicted is  1.8 Actual is  'Iris-virginica'
# Predicted is  1.8 Actual is  'Iris-virginica'
# Predicted is  2.5 Actual is  'Iris-virginica'
# Predicted is  2.3 Actual is  'Iris-virginica'
# Predicted is  1.9 Actual is  'Iris-virginica'
# Predicted is  0.3 Actual is  'Iris-setosa'
# Predicted is  0.4 Actual is  'Iris-setosa'
# Predicted is  0.2 Actual is  'Iris-setosa'
# Predicted is  0.2 Actual is  'Iris-setosa'
# Predicted is  0.2 Actual is  'Iris-setosa'
# Predicted is  0.3 Actual is  'Iris-setosa'
# Predicted is  0.2 Actual is  'Iris-setosa'
# Predicted is  0.2 Actual is  'Iris-setosa'
# Predicted is  0.4 Actual is  'Iris-setosa'
# Predicted is  0.3 Actual is  'Iris-setosa'
# Predicted is  0.4 Actual is  'Iris-setosa'
# Predicted is  0.2 Actual is  'Iris-setosa'
# Predicted is  0.1 Actual is  'Iris-setosa'
# Predicted is  0.2 Actual is  'Iris-setosa'
# Predicted is  0.2 Actual is  'Iris-setosa'
# Predicted is  0.2 Actual is  'Iris-setosa'
# Predicted is  0.2 Actual is  'Iris-setosa'
# Predicted is  0.3 Actual is  'Iris-setosa'
# Predicted is  0.2 Actual is  'Iris-setosa'
# Predicted is  1.6 Actual is  'Iris-versicolor'
# Predicted is  1.3 Actual is  'Iris-versicolor'
# Predicted is  1.3 Actual is  'Iris-versicolor'
# Predicted is  1.3 Actual is  'Iris-versicolor'
# Predicted is  1.3 Actual is  'Iris-versicolor'
# Predicted is  1.5 Actual is  'Iris-versicolor'
# Predicted is  1.0 Actual is  'Iris-versicolor'
# Predicted is  1.5 Actual is  'Iris-versicolor'
# Predicted is  1.3 Actual is  'Iris-versicolor'
# Predicted is  1.2 Actual is  'Iris-versicolor'
# Predicted is  1.0 Actual is  'Iris-versicolor'
# Predicted is  1.3 Actual is  'Iris-versicolor'
# Predicted is  2.4 Actual is  'Iris-virginica'
# Predicted is  1.8 Actual is  'Iris-virginica'
# Predicted is  1.5 Actual is  'Iris-virginica'
# Predicted is  1.8 Actual is  'Iris-virginica'
# Predicted is  2.1 Actual is  'Iris-virginica'
# Predicted is  1.9 Actual is  'Iris-virginica'
# Predicted is  2.3 Actual is  'Iris-virginica'
# Predicted is  2.1 Actual is  'Iris-virginica'
# Predicted is  2.2 Actual is  'Iris-virginica'
# Predicted is  2.2 Actual is  'Iris-virginica'
# Predicted is  1.8 Actual is  'Iris-virginica'
# Predicted is  2.1 Actual is  'Iris-virginica'
# Predicted is  2.1 Actual is  'Iris-virginica'
# Predicted is  2.0 Actual is  'Iris-virginica'
# Predicted is  2.4 Actual is  'Iris-virginica'
# Accuracy: 0.0%
